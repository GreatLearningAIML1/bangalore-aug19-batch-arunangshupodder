# %% [markdown]
# # K nearest neighbors

# %% [markdown]
# KNN falls in the supervised learning family of algorithms. Informally, this means that we are given a labelled dataset consiting of training observations (x, y) and would like to capture the relationship between x and y. More formally, our goal is to learn a function h: X→Y so that given an unseen observation x, h(x) can confidently predict the corresponding output y.
#
# In this module we will explore the inner workings of KNN, choosing the optimal K values and using KNN from scikit-learn.

# %% [markdown]
# ## Overview
#
# 1. Read the problem statement.
#
# 2. Get the dataset.
#
# 3. Explore the dataset.
#
# 4. Pre-processing of dataset.
#
# 5. Visualization
#
# 6. Transform the dataset for building machine learning model.
#
# 7. Split data into train, test set.
#
# 8. Build Model.
#
# 9. Apply the model.
#
# 10. Evaluate the model.
#
# 11. Finding Optimal K value
#
# 12. Repeat 7, 8, 9 steps.

# %% [markdown]
# ### Dataset
#
# The data set we’ll be using is the Iris Flower Dataset which was first introduced in 1936 by the famous statistician Ronald Fisher and consists of 50 observations from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals.
#
# **Download the dataset here:**
# - https://www.kaggle.com/uciml/iris
#
# **Train the KNN algorithm to be able to distinguish the species from one another given the measurements of the 4 features.**

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Question 1
#
# Import the data set and print 10 random rows from the data set
#
# Hint: use **sample()** function to get random rows

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Question 2 - Estimating missing values
#
# Its not good to remove the records having missing values all the time. We may end up loosing some data points. So, we will have to see how to replace those missing values with some estimated values (median)

# %% [markdown]
# Calculate the number of missing values per column
# - don't use loops

# %% [markdown]
# Fill missing values with median of that particular column

# %% [markdown]
# ### Question 3 - Dealing with categorical data
#
# Change all the classes to numericals (0 to 2)
#
# Hint: use **LabelEncoder()**

# %% [markdown]
# ### Question 4
#
# Observe the association of each independent variable with target variable and drop variables from feature set having correlation in range -0.1 to 0.1 with target variable.
#
# Hint: use **corr()**

# %% [markdown]
# ### Question 5
#
# Observe the independent variables variance and drop such variables having no variance or almost zero variance (variance < 0.1). They will be having almost no influence on the classification
#
# Hint: use **var()**

# %% [markdown]
# ### Question 6
#
# Plot the scatter matrix for all the variables.
#
# Hint: use **pandas.plotting.scatter_matrix()**
#
# you can also use pairplot()

# %% [markdown]
# ## Split the dataset into training and test sets

# %% [markdown]
# ### Question 7
#
# Split the dataset into training and test sets with 80-20 ratio
#
# Hint: use **train_test_split()**

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 8
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 9 - Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %% [markdown]
# ## Plot accuracy

# %% [markdown]
# ### Question 10
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %% [markdown]
# # Breast cancer dataset

# %% [markdown]
# ## Read data

# %% [markdown]
# ### Question 1
# Read the data given in bc2.csv file

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %%
bc2_df = pd.read_csv("bc2.csv")

# %%
bc2_df.head()
# Out:
#         ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0  1000025               5          1           1                  1
# 1  1002945               5          4           4                  5
# 2  1015425               3          1           1                  1
# 3  1016277               6          8           8                  1
# 4  1017023               4          1           1                  3
#
#    Single Epithelial Cell Size Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# 0                            2           1                3                1
# 1                            7          10                3                2
# 2                            2           2                3                1
# 3                            3           4                3                7
# 4                            2           1                3                1
#
#    Mitoses  Class
# 0        1      2
# 1        1      2
# 2        1      2
# 3        1      2
# 4        1      2

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Question 2
# Observe the no.of records in dataset and type of each column

# %%
bc2_df.shape[0]
# Out:
# 699

# %%
bc2_df.dtypes
# Out:
# ID                              int64
# ClumpThickness                  int64
# Cell Size                       int64
# Cell Shape                      int64
# Marginal Adhesion               int64
# Single Epithelial Cell Size     int64
# Bare Nuclei                    object
# Normal Nucleoli                 int64
# Bland Chromatin                 int64
# Mitoses                         int64
# Class                           int64
# dtype: object

# %% [markdown]
# ### Question 3
# Use summary statistics to check if missing values, outlier and encoding treament is necessary
#
# Hint: use **describe()**

# %%
bc2_df.describe()
# Out:
#                  ID  ClumpThickness   Cell Size  Cell Shape  \
# count  6.990000e+02      699.000000  699.000000  699.000000
# mean   1.071704e+06        4.417740    3.134478    3.207439
# std    6.170957e+05        2.815741    3.051459    2.971913
# min    6.163400e+04        1.000000    1.000000    1.000000
# 25%    8.706885e+05        2.000000    1.000000    1.000000
# 50%    1.171710e+06        4.000000    1.000000    1.000000
# 75%    1.238298e+06        6.000000    5.000000    5.000000
# max    1.345435e+07       10.000000   10.000000   10.000000
#
#        Marginal Adhesion  Single Epithelial Cell Size  Normal Nucleoli  \
# count         699.000000                   699.000000       699.000000
# mean            2.806867                     3.216023         3.437768
# std             2.855379                     2.214300         2.438364
# min             1.000000                     1.000000         1.000000
# 25%             1.000000                     2.000000         2.000000
# 50%             1.000000                     2.000000         3.000000
# 75%             4.000000                     4.000000         5.000000
# max            10.000000                    10.000000        10.000000
#
#        Bland Chromatin     Mitoses       Class
# count       699.000000  699.000000  699.000000
# mean          2.866953    1.589413    2.689557
# std           3.053634    1.715078    0.951273
# min           1.000000    1.000000    2.000000
# 25%           1.000000    1.000000    2.000000
# 50%           1.000000    1.000000    2.000000
# 75%           4.000000    1.000000    4.000000
# max          10.000000   10.000000    4.000000

# %% [markdown]
# #### Check Missing Values

# %%
bc2_df.isna().sum()
# Out:
# ID                             0
# ClumpThickness                 0
# Cell Size                      0
# Cell Shape                     0
# Marginal Adhesion              0
# Single Epithelial Cell Size    0
# Bare Nuclei                    0
# Normal Nucleoli                0
# Bland Chromatin                0
# Mitoses                        0
# Class                          0
# dtype: int64

# %% [markdown]
# ### Question 4
# #### Check how many `?` are there in Bare Nuclei feature (they are also unknown or missing values).

# %%
bc2_df[bc2_df["Bare Nuclei"] == "?"].shape[0]
# Out:
# 16

# %% [markdown]
# #### Replace them with the 'top' value of the describe function of Bare Nuclei feature
#
# Hint: give value of parameter include='all' in describe function

# %%
max_value = np.max(bc2_df["Bare Nuclei"].replace({'?':'0'}).astype(int))
bc2_df["Bare Nuclei"] = bc2_df["Bare Nuclei"].replace({'?':max_value.astype(str)})

# %%
bc2_df
# Out:
#           ID  ClumpThickness  Cell Size  Cell Shape  Marginal Adhesion  \
# 0    1000025               5          1           1                  1
# 1    1002945               5          4           4                  5
# 2    1015425               3          1           1                  1
# 3    1016277               6          8           8                  1
# 4    1017023               4          1           1                  3
# 5    1017122               8         10          10                  8
# 6    1018099               1          1           1                  1
# 7    1018561               2          1           2                  1
# 8    1033078               2          1           1                  1
# 9    1033078               4          2           1                  1
# 10   1035283               1          1           1                  1
# 11   1036172               2          1           1                  1
# 12   1041801               5          3           3                  3
# 13   1043999               1          1           1                  1
# 14   1044572               8          7           5                 10
# 15   1047630               7          4           6                  4
# 16   1048672               4          1           1                  1
# 17   1049815               4          1           1                  1
# 18   1050670              10          7           7                  6
# 19   1050718               6          1           1                  1
# 20   1054590               7          3           2                 10
# 21   1054593              10          5           5                  3
# 22   1056784               3          1           1                  1
# 23   1057013               8          4           5                  1
# 24   1059552               1          1           1                  1
# 25   1065726               5          2           3                  4
# 26   1066373               3          2           1                  1
# 27   1066979               5          1           1                  1
# 28   1067444               2          1           1                  1
# 29   1070935               1          1           3                  1
# ..       ...             ...        ...         ...                ...
# 669  1350423               5         10          10                  8
# 670  1352848               3         10           7                  8
# 671  1353092               3          2           1                  2
# 672  1354840               2          1           1                  1
# 673  1354840               5          3           2                  1
# 674  1355260               1          1           1                  1
# 675  1365075               4          1           4                  1
# 676  1365328               1          1           2                  1
# 677  1368267               5          1           1                  1
# 678  1368273               1          1           1                  1
# 679  1368882               2          1           1                  1
# 680  1369821              10         10          10                 10
# 681  1371026               5         10          10                 10
# 682  1371920               5          1           1                  1
# 683   466906               1          1           1                  1
# 684   466906               1          1           1                  1
# 685   534555               1          1           1                  1
# 686   536708               1          1           1                  1
# 687   566346               3          1           1                  1
# 688   603148               4          1           1                  1
# 689   654546               1          1           1                  1
# 690   654546               1          1           1                  3
# 691   695091               5         10          10                  5
# 692   714039               3          1           1                  1
# 693   763235               3          1           1                  1
# 694   776715               3          1           1                  1
# 695   841769               2          1           1                  1
# 696   888820               5         10          10                  3
# 697   897471               4          8           6                  4
# 698   897471               4          8           8                  5
#
#      Single Epithelial Cell Size Bare Nuclei  Normal Nucleoli  \
# 0                              2           1                3
# 1                              7          10                3
# 2                              2           2                3
# 3                              3           4                3
# 4                              2           1                3
# 5                              7          10                9
# 6                              2          10                3
# 7                              2           1                3
# 8                              2           1                1
# 9                              2           1                2
# 10                             1           1                3
# 11                             2           1                2
# 12                             2           3                4
# 13                             2           3                3
# 14                             7           9                5
# 15                             6           1                4
# 16                             2           1                2
# 17                             2           1                3
# 18                             4          10                4
# 19                             2           1                3
# 20                             5          10                5
# 21                             6           7                7
# 22                             2           1                2
# 23                             2          10                7
# 24                             2           1                3
# 25                             2           7                3
# 26                             1           1                2
# 27                             2           1                2
# 28                             2           1                2
# 29                             2           1                1
# ..                           ...         ...              ...
# 669                            5           5                7
# 670                            5           8                7
# 671                            2           1                3
# 672                            2           1                3
# 673                            3           1                1
# 674                            2           1                2
# 675                            2           1                1
# 676                            2           1                2
# 677                            2           1                1
# 678                            2           1                1
# 679                            2           1                1
# 680                            5          10               10
# 681                            4          10                5
# 682                            2           1                3
# 683                            2           1                1
# 684                            2           1                1
# 685                            2           1                1
# 686                            2           1                1
# 687                            2           1                2
# 688                            2           1                1
# 689                            2           1                1
# 690                            2           1                1
# 691                            4           5                4
# 692                            2           1                1
# 693                            2           1                2
# 694                            3           2                1
# 695                            2           1                1
# 696                            7           3                8
# 697                            3           4               10
# 698                            4           5               10
#
#      Bland Chromatin  Mitoses  Class
# 0                  1        1      2
# 1                  2        1      2
# 2                  1        1      2
# 3                  7        1      2
# 4                  1        1      2
# 5                  7        1      4
# 6                  1        1      2
# 7                  1        1      2
# 8                  1        5      2
# 9                  1        1      2
# 10                 1        1      2
# 11                 1        1      2
# 12                 4        1      4
# 13                 1        1      2
# 14                 5        4      4
# 15                 3        1      4
# 16                 1        1      2
# 17                 1        1      2
# 18                 1        2      4
# 19                 1        1      2
# 20                 4        4      4
# 21                10        1      4
# 22                 1        1      2
# 23                 3        1      4
# 24                 1        1      2
# 25                 6        1      4
# 26                 1        1      2
# 27                 1        1      2
# 28                 1        1      2
# 29                 1        1      2
# ..               ...      ...    ...
# 669               10        1      4
# 670                4        1      4
# 671                1        1      2
# 672                1        1      2
# 673                1        1      2
# 674                1        1      2
# 675                1        1      2
# 676                1        1      2
# 677                1        1      2
# 678                1        1      2
# 679                1        1      2
# 680               10        7      4
# 681                6        3      4
# 682                2        1      2
# 683                1        1      2
# 684                1        1      2
# 685                1        1      2
# 686                1        1      2
# 687                3        1      2
# 688                1        1      2
# 689                1        8      2
# 690                1        1      2
# 691                4        1      4
# 692                1        1      2
# 693                1        2      2
# 694                1        1      2
# 695                1        1      2
# 696               10        2      4
# 697                6        1      4
# 698                4        1      4
#
# [699 rows x 11 columns]

# %% [markdown]
# ### Question 5
# #### Find the distribution of target variable (Class)

# %%
bc2_df["Class"].value_counts()
# Out:
# 2    458
# 4    241
# Name: Class, dtype: int64

# %% [markdown]
# #### Plot the distribution of target variable using histogram

# %%
#plt.hist(bc2_df["Class"], bins=10)
#plt.show()

sns.distplot(bc2_df["Class"])

# %% [markdown]
# #### Convert the datatype of Bare Nuclei to `int`

# %%
bc2_df["Bare Nuclei"] = bc2_df["Bare Nuclei"].astype(int)
bc2_df["Bare Nuclei"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# ### Question 6
# Plot Scatter Matrix to understand the distribution of variables and check if any variables are collinear and drop one of them.

# %%
#sns.pairplot(bc2_df,hue="Class")

# %%
bc2_df.corr()
# Out:
#                                    ID  ClumpThickness  Cell Size  Cell Shape  \
# ID                           1.000000       -0.055308  -0.041603   -0.041576
# ClumpThickness              -0.055308        1.000000   0.644913    0.654589
# Cell Size                   -0.041603        0.644913   1.000000    0.906882
# Cell Shape                  -0.041576        0.654589   0.906882    1.000000
# Marginal Adhesion           -0.064878        0.486356   0.705582    0.683079
# Single Epithelial Cell Size -0.045528        0.521816   0.751799    0.719668
# Bare Nuclei                 -0.109068        0.552554   0.654290    0.680941
# Normal Nucleoli             -0.060051        0.558428   0.755721    0.735948
# Bland Chromatin             -0.052072        0.535835   0.722865    0.719446
# Mitoses                     -0.034901        0.350034   0.458693    0.438911
# Class                       -0.080226        0.716001   0.817904    0.818934
#
#                              Marginal Adhesion  Single Epithelial Cell Size  \
# ID                                   -0.064878                    -0.045528
# ClumpThickness                        0.486356                     0.521816
# Cell Size                             0.705582                     0.751799
# Cell Shape                            0.683079                     0.719668
# Marginal Adhesion                     1.000000                     0.599599
# Single Epithelial Cell Size           0.599599                     1.000000
# Bare Nuclei                           0.628526                     0.547466
# Normal Nucleoli                       0.666715                     0.616102
# Bland Chromatin                       0.603352                     0.628881
# Mitoses                               0.417633                     0.479101
# Class                                 0.696800                     0.682785
#
#                              Bare Nuclei  Normal Nucleoli  Bland Chromatin  \
# ID                             -0.109068        -0.060051        -0.052072
# ClumpThickness                  0.552554         0.558428         0.535835
# Cell Size                       0.654290         0.755721         0.722865
# Cell Shape                      0.680941         0.735948         0.719446
# Marginal Adhesion               0.628526         0.666715         0.603352
# Single Epithelial Cell Size     0.547466         0.616102         0.628881
# Bare Nuclei                     1.000000         0.647730         0.556131
# Normal Nucleoli                 0.647730         1.000000         0.665878
# Bland Chromatin                 0.556131         0.665878         1.000000
# Mitoses                         0.313539         0.344169         0.428336
# Class                           0.769854         0.756616         0.712244
#
#                               Mitoses     Class
# ID                          -0.034901 -0.080226
# ClumpThickness               0.350034  0.716001
# Cell Size                    0.458693  0.817904
# Cell Shape                   0.438911  0.818934
# Marginal Adhesion            0.417633  0.696800
# Single Epithelial Cell Size  0.479101  0.682785
# Bare Nuclei                  0.313539  0.769854
# Normal Nucleoli              0.344169  0.756616
# Bland Chromatin              0.428336  0.712244
# Mitoses                      1.000000  0.423170
# Class                        0.423170  1.000000

# %%
bc2_df.drop("Cell Size",axis=1,inplace=True)

# %% [markdown]
# ## Train test split

# %% [markdown]
# ### Question 7
# #### Divide the dataset into feature set and target set

# %%
X = bc2_df.drop("Class",axis=1)
y = bc2_df["Class"]

# %% [markdown]
# #### Divide the Training and Test sets in 70:30

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1)

# %%
X_train.head()
# Out:
#           ID  ClumpThickness  Cell Shape  Marginal Adhesion  \
# 146  1185609               3           5                  2
# 347   831268               1           1                  1
# 286   529329              10          10                 10
# 165  1197979               4           1                  1
# 493  1142706               5          10                 10
#
#      Single Epithelial Cell Size  Bare Nuclei  Normal Nucleoli  \
# 146                            6            8                4
# 347                            1            1                1
# 286                           10           10                4
# 165                            2            2                3
# 493                            6           10                6
#
#      Bland Chromatin  Mitoses
# 146                1        1
# 347                3        1
# 286               10       10
# 165                2        1
# 493                5        2

# %%
y_train.head()
# Out:
# 146    4
# 347    2
# 286    4
# 165    2
# 493    4
# Name: Class, dtype: int64

# %%
X_test.head()
# Out:
#           ID  ClumpThickness  Cell Shape  Marginal Adhesion  \
# 584  1217717               5           1                  6
# 417  1239967               1           1                  1
# 606   353098               4           1                  2
# 349   832567               4           3                  5
# 134  1180831               3           1                  1
#
#      Single Epithelial Cell Size  Bare Nuclei  Normal Nucleoli  \
# 584                            3            1                1
# 417                            2            1                2
# 606                            2            1                1
# 349                            3            8                7
# 134                            3            1                2
#
#      Bland Chromatin  Mitoses
# 584                1        1
# 417                1        1
# 606                1        1
# 349                6        1
# 134                1        1

# %%
y_test.head()
# Out:
# 584    2
# 417    2
# 606    2
# 349    4
# 134    2
# Name: Class, dtype: int64

# %% [markdown]
# ## Scale the data

# %% [markdown]
# ### Question 8
# Standardize the data
#
# Hint: use **StandardScaler()**

# %%
sc=StandardScaler()
sc.fit(X_train)
scaledX_train = sc.transform(X_train)

# %% [markdown]
# ## Build Model

# %% [markdown]
# ### Question 9
#
# Build the model and train and test on training and test sets respectively using **scikit-learn**.
#
# Print the Accuracy of the model with different values of **k = 3, 5, 9**
#
# Hint: For accuracy you can check **accuracy_score()** in scikit-learn

# %%
acc_list = []

# %%
knn3=KNeighborsClassifier(n_neighbors=3)
scaledX_test = sc.transform(X_test)
knn3.fit(scaledX_train,y_train)
print("What is the Testing Accuracy")
print(knn3.score(scaledX_test,y_test))
print("What is the Training Accuracy")
print(knn3.score(scaledX_train,y_train))
# Out:
# What is the Testing Accuracy
# 0.9619047619047619
# What is the Training Accuracy
# 0.967280163599182

# %%
knn5=KNeighborsClassifier(n_neighbors=5)
scaledX_test = sc.transform(X_test)
knn5.fit(scaledX_train,y_train)
print("What is the Testing Accuracy")
print(knn5.score(scaledX_test,y_test))
print("What is the Training Accuracy")
print(knn5.score(scaledX_train,y_train))
# Out:
# What is the Testing Accuracy
# 0.9666666666666667
# What is the Training Accuracy
# 0.967280163599182

# %%
knn9=KNeighborsClassifier(n_neighbors=9)
scaledX_test = sc.transform(X_test)
knn9.fit(scaledX_train,y_train)
print("What is the Testing Accuracy")
print(knn9.score(scaledX_test,y_test))
print("What is the Training Accuracy")
print(knn9.score(scaledX_train,y_train))
# Out:
# What is the Testing Accuracy
# 0.9619047619047619
# What is the Training Accuracy
# 0.9631901840490797

# %% [markdown]
# ## Find optimal value of K

# %% [markdown]
# ### Question 10
# Finding Optimal value of k
#
# - Run the KNN with no of neighbours to be 1, 3, 5 ... 19
# - Find the **optimal number of neighbours** from the above list

# %%
neighbors = np.arange(1,20,2)
train_accuracy_plot = np.empty(len(neighbors))
test_accuracy_plot = np.empty(len(neighbors))
# Loop over different values of k
for i,k in enumerate(neighbors):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1)
    sc=StandardScaler()
    scaledX_train = sc.fit_transform(X_train)
    scaledX_test = sc.transform(X_test)
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(scaledX_train,y_train)
    #Compute accuracy on the training set
    train_accuracy_plot[i] = knn.score(scaledX_train,y_train)
    print("What is the Train Accuracy for k="+str(k))
    print(train_accuracy_plot[i])
    #Compute accuracy on the testing set
    test_accuracy_plot[i] = knn.score(scaledX_test,y_test)
    print("What is the Test Accuracy for k="+str(k))
    print(test_accuracy_plot[i])
# Out:
# What is the Train Accuracy for k=1
# 1.0
# What is the Test Accuracy for k=1
# 0.9619047619047619
# What is the Train Accuracy for k=3
# 0.967280163599182
# What is the Test Accuracy for k=3
# 0.9619047619047619
# What is the Train Accuracy for k=5
# 0.967280163599182
# What is the Test Accuracy for k=5
# 0.9666666666666667
# What is the Train Accuracy for k=7
# 0.9611451942740287
# What is the Test Accuracy for k=7
# 0.9619047619047619
# What is the Train Accuracy for k=9
# 0.9631901840490797
# What is the Test Accuracy for k=9
# 0.9619047619047619
# What is the Train Accuracy for k=11
# 0.9652351738241309
# What is the Test Accuracy for k=11
# 0.9619047619047619
# What is the Train Accuracy for k=13
# 0.9652351738241309
# What is the Test Accuracy for k=13
# 0.9619047619047619
# What is the Train Accuracy for k=15
# 0.967280163599182
# What is the Test Accuracy for k=15
# 0.9619047619047619
# What is the Train Accuracy for k=17
# 0.967280163599182
# What is the Test Accuracy for k=17
# 0.9523809523809523
# What is the Train Accuracy for k=19
# 0.967280163599182
# What is the Test Accuracy for k=19
# 0.9571428571428572

# %%
print("The optimal value of k is 5")
# Out:
# The optimal value of k is 5

# %% [markdown]
# ## Plot accuracy

# %% [markdown]
# ### Question 11
#
# Plot accuracy score vs k (with k value on X-axis) using matplotlib.

# %%
# Generate plot
plt.title('k-NN: Varying Number of Neighbors')
plt.plot(neighbors, test_accuracy_plot, label = 'Testing Accuracy')
plt.plot(neighbors, train_accuracy_plot, label = 'Training Accuracy')
plt.legend()
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.show()
